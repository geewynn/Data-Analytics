# %%
import pandas as pd
import requests
from pandas.io.json import json_normalize

# %%
headers = {'Authorization':
           'Bearer AAAAAAAAAAAAAAAAAAAAAOY1BAEAAAAArLdUF5YmIR9TJswiJVobIFyT4DY%3D6reni84ARGSFRzPhzK05ztajvL473oI9mSAGzGJ9IvtDaGPDbK'}

# %%
tao_url = 'https://api.twitter.com/1.1/statuses/user_timeline.json?tweet.format&expansions&screen_name=_Taaooma&include_rts=False&count=1000'

response = requests.get(tao_url, 
                headers=headers)

# %%
data = response.json()

# %%
data[5]
# Out:
# {'created_at': 'Fri Feb 21 21:48:30 +0000 2020',
#  'id': 1230972589977239552,
#  'id_str': '1230972589977239552',
#  'text': 'Meeeeeeee right HERE!!!!!😂😂😂 https://t.co/xwqlsuXOh2',
#  'truncated': False,
#  'entities': {'hashtags': [],
#   'symbols': [],
#   'user_mentions': [],
#   'urls': [{'url': 'https://t.co/xwqlsuXOh2',
#     'expanded_url': 'https://twitter.com/AinaTemitope10/status/1230972331142631426',
#     'display_url': 'twitter.com/AinaTemitope10…',
#     'indices': [29, 52]}]},
#  'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'in_reply_to_screen_name': None,
#  'user': {'id': 978487021957210112,
#   'id_str': '978487021957210112',
#   'name': 'MÓŃKELE ❤️',
#   'screen_name': '_Taaooma',
#   'location': 'Lagos, Nigeria',
# ...

# %%
twit = json_normalize(data, max_level=0)

# %%
twit.head(3)
# Out:
#                        created_at                   id               id_str  \
# 0  Sun Feb 23 12:12:02 +0000 2020  1231552294350675968  1231552294350675968
# 1  Sun Feb 23 08:00:54 +0000 2020  1231489092040450048  1231489092040450048
# 2  Sun Feb 23 07:42:22 +0000 2020  1231484430797152257  1231484430797152257
#
#                                                 text  truncated  \
# 0  Happy birthday my sweetheart, may God keep ble...      False
# 1                                 @Mr_dotman Noon 😩😩      False
# 2  I ate Amala yesterday after a long time 😩. Oh ...      False
#
#                                             entities  \
# 0  {'hashtags': [], 'symbols': [], 'user_mentions...
# 1  {'hashtags': [], 'symbols': [], 'user_mentions...
# 2  {'hashtags': [], 'symbols': [], 'user_mentions...
#
#                                               source  in_reply_to_status_id  \
# 0  <a href="http://twitter.com/download/iphone" r...                    NaN
# ...

# %%
twit.drop(twit[twit['extended_entities'].isna()].index, inplace=True)

# %%
twit.dropna(how='any', axis=1, inplace=True)

# %%
twit['entity_type'] = twit['extended_entities'].apply(lambda x: x['media'][0].get('type'))

# %%
twit.head()
# Out:
#                         created_at                   id               id_str  \
# 6   Fri Feb 21 21:47:31 +0000 2020  1230972341225689088  1230972341225689088
# 8   Fri Feb 21 21:17:41 +0000 2020  1230964834163920897  1230964834163920897
# 10  Fri Feb 21 09:45:39 +0000 2020  1230790679598653440  1230790679598653440
# 11  Fri Feb 21 08:26:51 +0000 2020  1230770846186102785  1230770846186102785
# 22  Tue Feb 18 23:45:10 +0000 2020  1229914785426309120  1229914785426309120
#
#                                                  text  truncated  \
# 6                   @Demo__UK https://t.co/wXdhJvNut7      False
# 8                Bomboclat !! https://t.co/fyH6h0ti4c      False
# 10  These days you have to be smart with your wife...      False
# 11  Be You \nThe world will adjust 🥰 https://t.co/...      False
# 22  @TitusJulius9 No be me and you o https://t.co/...      False
#
#                                              entities  \
# ...

# %%
videos = twit[twit['entity_type'] == 'video']

# %%
twyse_url = 'https://api.twitter.com/1.1/statuses/user_timeline.json?tweet.format&expansions&screen_name=Twyse_116&&count=1000'

response = requests.get(twyse_url, 
                headers=headers)

# %%
twyse = response.json()

twyse_data = json_normalize(twyse, max_level=0)

# %%
twyse_data.drop(twyse_data[twyse_data['extended_entities'].isna()].index, inplace=True)
twyse_data.dropna(how='any', axis=1, inplace=True)
twyse_data['entity_type'] = twyse_data['extended_entities'].apply(lambda x: x['media'][0].get('type'))

# %%
twyse_data.head()
# Out:
#                         created_at                   id               id_str  \
# 36  Sun Feb 23 14:31:53 +0000 2020  1231587485920178176  1231587485920178176
# 58  Sun Feb 23 03:31:42 +0000 2020  1231421348850868230  1231421348850868230
# 69  Sat Feb 22 15:18:47 +0000 2020  1231236903338418176  1231236903338418176
# 72  Sat Feb 22 15:12:37 +0000 2020  1231235348715442183  1231235348715442183
# 92  Sat Feb 22 13:53:30 +0000 2020  1231215439771992064  1231215439771992064
#
#                                                  text  truncated  \
# 36  For the first time 😂😩 https://t.co/yRSkc14cnx ...      False
# 58  RT @chuuzus: since we are still talking about ...      False
# 69  RT @funnyjhay_: Man like @twyse_116 🥺🔥\nFantab...      False
# 72  RT @MrDesmond_: Twyse and mr macaroni no go ki...      False
# 92                            https://t.co/HHb8neugDk      False
#
#                                              entities  \
# ...

# %%
twyse_video = twyse_data[twyse_data['entity_type'] == 'video']

# %%
#twyse_data[twyse_data['extended_entities'].isna() == False]
twyse_video
# Out:
#                          created_at                   id               id_str  \
# 36   Sun Feb 23 14:31:53 +0000 2020  1231587485920178176  1231587485920178176
# 72   Sat Feb 22 15:12:37 +0000 2020  1231235348715442183  1231235348715442183
# 133  Sat Feb 22 09:19:40 +0000 2020  1231146528196190208  1231146528196190208
#
#                                                   text  truncated  \
# 36   For the first time 😂😩 https://t.co/yRSkc14cnx ...      False
# 72   RT @MrDesmond_: Twyse and mr macaroni no go ki...      False
# 133  Wehcome toe Ooin Secondary School 😭⁣ https://t...      False
#
#                                               entities  \
# 36   {'hashtags': [], 'symbols': [], 'user_mentions...
# 72   {'hashtags': [], 'symbols': [], 'user_mentions...
# 133  {'hashtags': [], 'symbols': [], 'user_mentions...
#
#                                                 source  \
# 36   <a href="http://twitter.com/download/iphone" r...
# ...
